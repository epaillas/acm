# %% [markdown]
# # Control plots for the `prepare_sim.py` script

# %%
# Imports 
import os
import sys
import gc
from pathlib import Path
import time
import yaml
import h5py
import asdf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

config = yaml.safe_load(open('config_c000.yaml', 'r'))

sim_dir = Path(config['sim_params']['sim_dir'])
simname = config['sim_params']['sim_name']
z = config['sim_params']['z_mock']

subsample_dir = Path(config['sim_params']['subsample_dir'])

want_ranks = config['HOD_params']['want_ranks']
newseed = 600

# %% [markdown]
# ## Completeness check
#
# The `prepare_sim.py` script should only return files for a slab if the slab was correctly generated. This is a check to see if all the slabs have their files generated.

# %%
numslabs = 34 # Number of expected slabs per cosmology

cosmo_list = [i for i in range(5)] + [13] + [i for i in range(100, 127)] + [i for i in range(130, 182)]
expected_slab_number = [numslabs for i in range(len(cosmo_list))] # 34 slabs per cosmology ?

actual_slab_number = []
for i in range(len(cosmo_list)):
    savedir = str(subsample_dir / f'AbacusSummit_base_c{cosmo_list[i]:03d}_ph000/z{z:.3f}/')
    
    missing_slabs_number = 0
    if not os.path.isdir(savedir):
        actual_slab_number.append(0)
        continue
    
    for i in range(numslabs):
        outfilename_halos = savedir + '/halos_xcom_'+str(i)+'_seed'+str(newseed)+'_abacushod_oldfenv_new.h5'
        outfilename_particles = savedir + '/particles_xcom_'+str(i)+'_seed'+str(newseed)+'_abacushod_oldfenv_new.h5'
        if want_ranks:
            outfilename_particles = savedir+'/particles_xcom_'+str(i)+'_seed'+str(newseed)+'_abacushod_oldfenv_withranks_new.h5'
        if not os.path.exists(outfilename_halos) or not os.path.exists(outfilename_particles):
            missing_slabs_number += 1

    actual_slab_number.append(numslabs - missing_slabs_number)
    
df = pd.DataFrame({'Cosmo': cosmo_list, 'Expected': expected_slab_number, 'Actual': actual_slab_number})

# Make df pretty
def color_cell_complete(val):
    if val == numslabs:
        color = '#006400'
    elif val == 0:
        color = '#8B0000'
    else:
        color = '#B8860B'
    return color

def row_cell_color(row):
    return [f"background-color: {color_cell_complete(val)}" for val in row]

def row_cell_bold(row, col=None):
    if col:
        return [f"font-weight: bold;" for val in row if val=='Cosmo']
    return [f"font-weight: bold;" for val in row]

def make_pretty(styler):
    styler.set_caption("Simulation completeness")
    styler.apply(row_cell_color, axis=1, subset=pd.IndexSlice[['Actual'],:])
    
    # Make first line as header when transposed
    styler.hide(axis=1) # hide columns numbers
    styler.apply(row_cell_bold, axis=1, subset=pd.IndexSlice[['Cosmo'],:]) # bold first line
    styler.apply_index(row_cell_bold, axis='index', col=True) # bold first column
    
    return styler

df.T.style.pipe(make_pretty)
# Out:
# <style type="text/css">
# #T_d4871_row0_col0, #T_d4871_row0_col1, #T_d4871_row0_col2, #T_d4871_row0_col3, #T_d4871_row0_col4, #T_d4871_row0_col5, #T_d4871_row0_col6, #T_d4871_row0_col7, #T_d4871_row0_col8, #T_d4871_row0_col9, #T_d4871_row0_col10, #T_d4871_row0_col11, #T_d4871_row0_col12, #T_d4871_row0_col13, #T_d4871_row0_col14, #T_d4871_row0_col15, #T_d4871_row0_col16, #T_d4871_row0_col17, #T_d4871_row0_col18, #T_d4871_row0_col19, #T_d4871_row0_col20, #T_d4871_row0_col21, #T_d4871_row0_col22, #T_d4871_row0_col23, #T_d4871_row0_col24, #T_d4871_row0_col25, #T_d4871_row0_col26, #T_d4871_row0_col27, #T_d4871_row0_col28, #T_d4871_row0_col29, #T_d4871_row0_col30, #T_d4871_row0_col31, #T_d4871_row0_col32, #T_d4871_row0_col33, #T_d4871_row0_col34, #T_d4871_row0_col35, #T_d4871_row0_col36, #T_d4871_row0_col37, #T_d4871_row0_col38, #T_d4871_row0_col39, #T_d4871_row0_col40, #T_d4871_row0_col41, #T_d4871_row0_col42, #T_d4871_row0_col43, #T_d4871_row0_col44, #T_d4871_row0_col45, #T_d4871_row0_col46, #T_d4871_row0_col47, #T_d4871_row0_col48, #T_d4871_row0_col49, #T_d4871_row0_col50, #T_d4871_row0_col51, #T_d4871_row0_col52, #T_d4871_row0_col53, #T_d4871_row0_col54, #T_d4871_row0_col55, #T_d4871_row0_col56, #T_d4871_row0_col57, #T_d4871_row0_col58, #T_d4871_row0_col59, #T_d4871_row0_col60, #T_d4871_row0_col61, #T_d4871_row0_col62, #T_d4871_row0_col63, #T_d4871_row0_col64, #T_d4871_row0_col65, #T_d4871_row0_col66, #T_d4871_row0_col67, #T_d4871_row0_col68, #T_d4871_row0_col69, #T_d4871_row0_col70, #T_d4871_row0_col71, #T_d4871_row0_col72, #T_d4871_row0_col73, #T_d4871_row0_col74, #T_d4871_row0_col75, #T_d4871_row0_col76, #T_d4871_row0_col77, #T_d4871_row0_col78, #T_d4871_row0_col79, #T_d4871_row0_col80, #T_d4871_row0_col81, #T_d4871_row0_col82, #T_d4871_row0_col83, #T_d4871_row0_col84 {
#   font-weight: bold;
# }
# #T_d4871_row2_col0, #T_d4871_row2_col1, #T_d4871_row2_col2, #T_d4871_row2_col3, #T_d4871_row2_col4, #T_d4871_row2_col5, #T_d4871_row2_col6, #T_d4871_row2_col7, #T_d4871_row2_col8, #T_d4871_row2_col9, #T_d4871_row2_col10, #T_d4871_row2_col11, #T_d4871_row2_col12, #T_d4871_row2_col13, #T_d4871_row2_col14, #T_d4871_row2_col15, #T_d4871_row2_col16, #T_d4871_row2_col17, #T_d4871_row2_col18, #T_d4871_row2_col19, #T_d4871_row2_col20, #T_d4871_row2_col21, #T_d4871_row2_col22, #T_d4871_row2_col23, #T_d4871_row2_col24, #T_d4871_row2_col25, #T_d4871_row2_col26, #T_d4871_row2_col27, #T_d4871_row2_col28, #T_d4871_row2_col29, #T_d4871_row2_col30, #T_d4871_row2_col31, #T_d4871_row2_col32, #T_d4871_row2_col33, #T_d4871_row2_col34, #T_d4871_row2_col35, #T_d4871_row2_col36, #T_d4871_row2_col37, #T_d4871_row2_col38, #T_d4871_row2_col39, #T_d4871_row2_col40, #T_d4871_row2_col41, #T_d4871_row2_col42, #T_d4871_row2_col43, #T_d4871_row2_col44, #T_d4871_row2_col45, #T_d4871_row2_col46, #T_d4871_row2_col47, #T_d4871_row2_col48, #T_d4871_row2_col49, #T_d4871_row2_col50, #T_d4871_row2_col51, #T_d4871_row2_col52, #T_d4871_row2_col53, #T_d4871_row2_col54, #T_d4871_row2_col55, #T_d4871_row2_col56, #T_d4871_row2_col57, #T_d4871_row2_col58, #T_d4871_row2_col59, #T_d4871_row2_col60, #T_d4871_row2_col61, #T_d4871_row2_col62, #T_d4871_row2_col63, #T_d4871_row2_col64, #T_d4871_row2_col65, #T_d4871_row2_col66, #T_d4871_row2_col67, #T_d4871_row2_col68, #T_d4871_row2_col69, #T_d4871_row2_col70, #T_d4871_row2_col71, #T_d4871_row2_col72, #T_d4871_row2_col73, #T_d4871_row2_col74, #T_d4871_row2_col75, #T_d4871_row2_col76, #T_d4871_row2_col77, #T_d4871_row2_col78, #T_d4871_row2_col79, #T_d4871_row2_col80, #T_d4871_row2_col81, #T_d4871_row2_col82, #T_d4871_row2_col83, #T_d4871_row2_col84 {
#   background-color: #006400;
# }
# #T_d4871_level0_row0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_d4871">
#   <caption>Simulation completeness</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4871_level0_row0" class="row_heading level0 row0" >Cosmo</th>
#       <td id="T_d4871_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_d4871_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_d4871_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_d4871_row0_col3" class="data row0 col3" >3</td>
#       <td id="T_d4871_row0_col4" class="data row0 col4" >4</td>
#       <td id="T_d4871_row0_col5" class="data row0 col5" >13</td>
#       <td id="T_d4871_row0_col6" class="data row0 col6" >100</td>
#       <td id="T_d4871_row0_col7" class="data row0 col7" >101</td>
#       <td id="T_d4871_row0_col8" class="data row0 col8" >102</td>
#       <td id="T_d4871_row0_col9" class="data row0 col9" >103</td>
#       <td id="T_d4871_row0_col10" class="data row0 col10" >104</td>
#       <td id="T_d4871_row0_col11" class="data row0 col11" >105</td>
#       <td id="T_d4871_row0_col12" class="data row0 col12" >106</td>
#       <td id="T_d4871_row0_col13" class="data row0 col13" >107</td>
#       <td id="T_d4871_row0_col14" class="data row0 col14" >108</td>
#       <td id="T_d4871_row0_col15" class="data row0 col15" >109</td>
#       <td id="T_d4871_row0_col16" class="data row0 col16" >110</td>
#       <td id="T_d4871_row0_col17" class="data row0 col17" >111</td>
#       <td id="T_d4871_row0_col18" class="data row0 col18" >112</td>
#       <td id="T_d4871_row0_col19" class="data row0 col19" >113</td>
#       <td id="T_d4871_row0_col20" class="data row0 col20" >114</td>
#       <td id="T_d4871_row0_col21" class="data row0 col21" >115</td>
#       <td id="T_d4871_row0_col22" class="data row0 col22" >116</td>
#       <td id="T_d4871_row0_col23" class="data row0 col23" >117</td>
#       <td id="T_d4871_row0_col24" class="data row0 col24" >118</td>
#       <td id="T_d4871_row0_col25" class="data row0 col25" >119</td>
#       <td id="T_d4871_row0_col26" class="data row0 col26" >120</td>
#       <td id="T_d4871_row0_col27" class="data row0 col27" >121</td>
#       <td id="T_d4871_row0_col28" class="data row0 col28" >122</td>
#       <td id="T_d4871_row0_col29" class="data row0 col29" >123</td>
#       <td id="T_d4871_row0_col30" class="data row0 col30" >124</td>
#       <td id="T_d4871_row0_col31" class="data row0 col31" >125</td>
#       <td id="T_d4871_row0_col32" class="data row0 col32" >126</td>
#       <td id="T_d4871_row0_col33" class="data row0 col33" >130</td>
#       <td id="T_d4871_row0_col34" class="data row0 col34" >131</td>
#       <td id="T_d4871_row0_col35" class="data row0 col35" >132</td>
#       <td id="T_d4871_row0_col36" class="data row0 col36" >133</td>
#       <td id="T_d4871_row0_col37" class="data row0 col37" >134</td>
#       <td id="T_d4871_row0_col38" class="data row0 col38" >135</td>
#       <td id="T_d4871_row0_col39" class="data row0 col39" >136</td>
#       <td id="T_d4871_row0_col40" class="data row0 col40" >137</td>
#       <td id="T_d4871_row0_col41" class="data row0 col41" >138</td>
#       <td id="T_d4871_row0_col42" class="data row0 col42" >139</td>
#       <td id="T_d4871_row0_col43" class="data row0 col43" >140</td>
#       <td id="T_d4871_row0_col44" class="data row0 col44" >141</td>
#       <td id="T_d4871_row0_col45" class="data row0 col45" >142</td>
#       <td id="T_d4871_row0_col46" class="data row0 col46" >143</td>
#       <td id="T_d4871_row0_col47" class="data row0 col47" >144</td>
#       <td id="T_d4871_row0_col48" class="data row0 col48" >145</td>
#       <td id="T_d4871_row0_col49" class="data row0 col49" >146</td>
#       <td id="T_d4871_row0_col50" class="data row0 col50" >147</td>
#       <td id="T_d4871_row0_col51" class="data row0 col51" >148</td>
#       <td id="T_d4871_row0_col52" class="data row0 col52" >149</td>
#       <td id="T_d4871_row0_col53" class="data row0 col53" >150</td>
#       <td id="T_d4871_row0_col54" class="data row0 col54" >151</td>
#       <td id="T_d4871_row0_col55" class="data row0 col55" >152</td>
#       <td id="T_d4871_row0_col56" class="data row0 col56" >153</td>
#       <td id="T_d4871_row0_col57" class="data row0 col57" >154</td>
#       <td id="T_d4871_row0_col58" class="data row0 col58" >155</td>
#       <td id="T_d4871_row0_col59" class="data row0 col59" >156</td>
#       <td id="T_d4871_row0_col60" class="data row0 col60" >157</td>
#       <td id=

# %% [markdown]
# ## Halo mass histogram
#
# All halo mass functions should roughly have the same shape. We plot them to check if they are similar.
#
# > Note : we have to plot them 10 by 10 because of the size of the files, which is too big to store all cosmologies in memory at once.

# %%
# Import references

save_path = '/pscratch/sd/s/sbouchar/00- Archives/Halo_mass_function/'

masses_full = np.load(save_path + f'masses_full_z{z:.3f}.npy')
masses_LRG = np.load(save_path + f'masses_LRG_z{z:.3f}.npy')
masses_BGS = np.load(save_path + f'masses_BGS.npy')
masses_alex_box = np.load(save_path + f'masses_alex_box_z{z:.3f}.npy')

# %%
# Load the halos only
halo_masses = []

folder_list = list(subsample_dir.glob('AbacusSummit_base_*'))[80:85]
folder_list.sort()

for folder in folder_list:
    start = time.time()
    simname = folder.name
    print(simname)

    # Particle mass for this cosmo
    halo_info_dir = sim_dir / simname / 'halos' / f'z{z:4.3f}' / 'halo_info'
    halo_info_fns = list( halo_info_dir.glob('*.asdf') )

    f = asdf.open(halo_info_fns[0], lazy_load=True, copy_arrays=False)
    header = f['header']

    params = {}
    params['Mpart'] = header['ParticleMassHMsun']

    # From AbacusHOD : Halo masses
    cosmo_dir = subsample_dir / simname / f'z{z:.3f}' 
    numslabs = len(list(cosmo_dir.glob('halos_xcom_*.h5'))) # Number of slabs for this cosmo (/!\ Changed from before)
    if numslabs == 0:
        print(f'Warning : No slabs found for cosmo {simname} !')
        continue
    elif numslabs != 34:
        print(f'Warning : Missing slabs ({numslabs}) to cosmo {simname} !')
        continue
        
    tmp_halo_masses = [] # Store the halo masses of the slabs
    for slab in range(numslabs):
        halofilename = cosmo_dir / f'halos_xcom_{slab}_seed600_abacushod_oldfenv' 
        halofilename = str(halofilename) + '_new.h5'
        newfile = h5py.File(halofilename, 'r')
        maskedhalos = newfile['halos']

        halo_mass = maskedhalos['N'] * params['Mpart']
        tmp_halo_masses.append(halo_mass)

    halo_masses.append(np.concatenate(tmp_halo_masses)) # Concatenate the halo masses in one array
    
    # cleanup to free memory
    del f
    del header
    del params
    del tmp_halo_masses
    del newfile
    del maskedhalos
    del halo_mass
    gc.collect()
    
    end = time.time()
    print(f'Time ({simname}) : {end-start:.2f}s')
# Out:
# AbacusSummit_base_c013_ph000
# Time (AbacusSummit_base_c013_ph000) : 15.03s
# AbacusSummit_base_c110_ph000
# Time (AbacusSummit_base_c110_ph000) : 14.46s
# AbacusSummit_base_c152_ph000
# Time (AbacusSummit_base_c152_ph000) : 17.75s
# AbacusSummit_base_c169_ph000
# Time (AbacusSummit_base_c169_ph000) : 18.51s
# AbacusSummit_base_c181_ph000
# Time (AbacusSummit_base_c181_ph000) : 17.78s

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 4))

# Plot references
ax.hist(np.log10(masses_full), bins=100, histtype='step', color='b', lw=1.5, alpha=0.5, label='Full')
ax.hist(np.log10(masses_LRG), bins=100, histtype='step', color='g', lw=1.5, alpha=0.5, label='LRG')
ax.hist(np.log10(masses_BGS), bins=100, histtype='step', color='y', lw=1.5, alpha=0.5, label='BGS')
ax.hist(np.log10(masses_alex_box), bins=100, histtype='step', color='r', lw=1.5, alpha=0.5, label='Alex Box')

for halo_mass in halo_masses:
    ax.hist(np.log10(halo_mass), bins=100, histtype='step', color='k', lw=1.5, alpha=0.2)

ax.set_yscale('log')
ax.legend(fontsize=8, loc='upper right')
ax.set_title(f'Halo mass function for {len(halo_masses)} different simulations at z=0.2 (references for c000)')
ax.set_xlabel(r'$\log_{10} M_{\rm halo}$')
ax.set_ylabel(r'$N_{\rm halo}$');

# %% [markdown]
# ## Corruption check
#
# Check if the files are corrupted by opening them. If h5py raises an error, the file is corrupte and should be computed again.

# %%
# Check we can open every file !!
sim_dir = '/global/cfs/cdirs/desi/cosmosim/Abacus/'
subsample_dir_base = '/pscratch/sd/s/sbouchar/abacus_subsamples_cleaned/'
z_mock = 0.2

cosmo_list = [i for i in range(5)] + [13] + [i for i in range(100, 127)] + [i for i in range(130, 182)]

for cosmo in cosmo_list:

    sim_name = f'AbacusSummit_base_c{cosmo:03d}_ph000'

    simname = Path(sim_name)
    sim_dir = Path(sim_dir)

    # create mock_dir if not created
    subsample_dir = \
        Path(subsample_dir_base) / simname / ('z%4.3f'%z_mock)


    halo_info_fns = \
                    list((sim_dir / simname / 'halos' / ('z%4.3f'%z_mock) / 'halo_info').glob('*.asdf'))
    f = asdf.open(halo_info_fns[0], lazy_load=True, copy_arrays=False)
    header = f['header']

    # settitng up chunking
    chunk = 0
    n_chunks = 1
    n_jump = int(np.ceil(len(halo_info_fns)/n_chunks))
    start = ((chunk)*n_jump)
    end = ((chunk+1)*n_jump)
    if end > len(halo_info_fns):
        end = len(halo_info_fns)
    lbox = header['BoxSize']

    for eslab in range(start, end):
        halofilename = subsample_dir / ('halos_xcom_%d_seed600_abacushod_oldfenv'%eslab)
        particlefilename = subsample_dir / ('particles_xcom_%d_seed600_abacushod_oldfenv'%eslab)
        


        particlefilename = str(particlefilename) + '_withranks'
        halofilename = str(halofilename) + '_new.h5'
        particlefilename = str(particlefilename) + '_new.h5'
        
        try : 
            newfile = h5py.File(halofilename, 'r')
        except:
            print(f'Error with {halofilename} in {simname} !')
            continue
        try:
            newpart = h5py.File(particlefilename, 'r')
        except:
            print(f'Error with {particlefilename} in {simname} !')
            continue
